# %% [markdown]
# <a href="https://colab.research.google.com/github/BMarlinVCU/INFO450F26/blob/main/Lesson5/football.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import requests

url = "https://raw.githubusercontent.com/BMarlinVCU/INFO450F26/refs/heads/main/Lesson5/soccer.json"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
data = response.json()
print(data)

# %%
data['matches'][103]
